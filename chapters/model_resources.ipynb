# %% [markdown]
# # Model Resources

# %% [markdown]
# ## Audio
#
# ### Music
#
# - https://iashin.ai/SpecVQGAN
# - https://www.riffusion.com/ (Pipe Spectograms generated by SpecVQGAN from an image into riffusion for further interpolation alongside text prompts)
# - https://github.com/v-iashin/SpecVQGAN
#
# ### Voice / TTS
#
# - https://github.com/archinetai/audio-ai-timeline
# - https://github.com/olaviinha/NeuralTextToAudio

# %% [markdown]
# ## Text
#
# - https://github.com/serp-ai/LLaMA-8bit-LoRA
# - https://github.com/juncongmoo/minichatgpt
# - https://github.com/juncongmoo/chatllama | https://chatllama.baseten.co/
# - https://www.youtube.com/watch?v=YqPYDWPYXFs
# - https://www.linkedin.com/in/omarsar/recent-activity/
# - https://www.linkedin.com/in/damienbenveniste/recent-activity/shares/

# %% [markdown]
# ## Video
#
# - https://runwayml.com/
# -

# %% [markdown]
# ## Image
#
# - https://www.advanced-innovation.io/ki-tools/civitai | https://civitai.com/
